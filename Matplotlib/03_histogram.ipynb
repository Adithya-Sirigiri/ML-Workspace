# %% [markdown]
# ## Histogram Plot

# %%
from matplotlib import pyplot as plt
list=[12, 18, 25, 30, 22, 27, 35, 40, 45, 50,15, 19, 23, 28, 32, 37, 42, 48, 53, 57,11, 16, 21, 26, 31, 36, 41, 46, 52, 58,14, 17, 24, 29, 34, 38, 43, 47, 51, 55,13, 20, 33, 39, 44, 49, 54, 56, 59, 60]
plt.hist(list)
plt.show()

# %%
from matplotlib import pyplot as plt
list=[12, 18, 25, 30, 22, 27, 35, 40, 45, 50,15, 19, 23, 28, 32, 37, 42, 48, 53, 57,11, 16, 21, 26, 31, 36, 41, 46, 52, 58,14, 17, 24, 29, 34, 38, 43, 47, 51, 55,13, 20, 33, 39, 44, 49, 54, 56, 59, 60]
plt.xlabel("Random numbers",fontsize=15)
plt.ylabel("frequency",fontsize=15)
plt.title("Histogram",fontsize=15)
plt.hist(list)
plt.show()

# %%
from matplotlib import pyplot as plt
random=[12, 18, 25, 30, 22, 27, 35, 40, 45, 50,15, 19, 23, 28, 32, 37, 42, 48, 53, 57,11, 16, 21, 26, 31, 36, 41, 46, 52, 58,14, 17, 24, 29, 34, 38, 43, 47, 51, 55,13, 20, 33, 39, 44, 49, 54, 56, 59, 60]
y=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Random numbers",fontsize=15)
plt.ylabel("frequency",fontsize=15)
plt.title("Histogram",fontsize=15)
plt.hist(random,color='g',bins=y,edgecolor='r',linewidth=1.5,linestyle=':')
plt.show()

# %%
from matplotlib import pyplot as plt
random=[12, 18, 25, 30, 22, 27, 35, 40, 45, 50,15, 19, 23, 28, 32, 37, 42, 48, 53, 57,11, 16, 21, 26, 31, 36, 41, 46, 52, 58,14, 17, 24, 29, 34, 38, 43, 47, 51, 55,13, 20, 33, 39, 44, 49, 54, 56, 59, 60]
y=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Random numbers",fontsize=15)
plt.ylabel("frequency",fontsize=15)
plt.title("Histogram",fontsize=15)
plt.hist(random,color='g',bins=y,edgecolor='r',linewidth=1.5,linestyle=':',cumulative=-1)
plt.show()

# %%
from matplotlib import pyplot as plt
random=[12, 18, 25, 30, 22, 27, 35, 40, 45, 50,15, 19, 23, 28, 32, 37, 42, 48, 53, 57,11, 16, 21, 26, 31, 36, 41, 46, 52, 58,14, 17, 24, 29, 34, 38, 43, 47, 51, 55,13, 20, 33, 39, 44, 49, 54, 56, 59, 60]
y=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Random numbers",fontsize=15)
plt.ylabel("frequency",fontsize=15)
plt.title("Histogram",fontsize=15)
plt.hist(random,color='g',bins=y,edgecolor='r',linewidth=1.5,linestyle=':',cumulative=-1,histtype='step')
plt.show()

# %%
from matplotlib import pyplot as plt
random=[12, 18, 25, 30, 22, 27, 35, 40, 45, 50,15, 19, 23, 28, 32, 37, 42, 48, 53, 57,11, 16, 21, 26, 31, 36, 41, 46, 52, 58,14, 17, 24, 29, 34, 38, 43, 47, 51, 55,13, 20, 33, 39, 44, 49, 54, 56, 59, 60]
y=[5,10,15,20,25,30,35,40,45,50,55,60]
plt.xlabel("Random numbers",fontsize=15)
plt.ylabel("frequency",fontsize=15)
plt.title("Histogram",fontsize=15)
plt.hist(random,color='g',bins=y,edgecolor='r',linewidth=1.5,linestyle=':',cumulative=-1,histtype='step',orientation='horizontal')
plt.show()
